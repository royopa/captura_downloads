# %%
import requests
import json
import base64

# %%
url = "https://apiapex.tesouro.gov.br/aria/v1/sistd/custom/historico?ano=2021&idSigla=1"

# %%
res = requests.get(
    url, headers={"User-Agent": "libcurl/7.64.1 r-curl/4.3.1 httr/1.4.2"}, verify=True
)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     484             try:
# --> 485                 cnx.do_handshake()
#     486             except OpenSSL.SSL.WantReadError:
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1933         result = _lib.SSL_do_handshake(self._ssl)
# -> 1934         self._raise_ssl_error(self._ssl, result)
#    1935
#
# ~\anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1670         else:
# -> 1671             _raise_current_error()
#    1672
#
# ~\anaconda3\lib\site-packages\OpenSSL\_util.py in exception_from_error_queue(exception_type)
#      53
# ---> 54     raise exception_type(errors)
#      55
#
# ...

# %%
res.status_code
# Out:
# 200

# %%
url = "https://www.anbima.com.br/informacoes/merc-sec-debentures/resultados/mdeb_23ago2021_di_percentual.asp"
res = requests.get(
    url, headers={"User-Agent": "libcurl/7.64.1 r-curl/4.3.1 httr/1.4.2"}, verify=True
)

# %%
res.status_code
# Out:
# 200

# %%
import datetime

# %%
now = datetime.datetime.now()

# %%
now.strftime("%b")
# Out:
# 'Aug'

# %%
import locale
import threading

from datetime import datetime
from contextlib import contextmanager


LOCALE_LOCK = threading.Lock()


@contextmanager
def setlocale(name):
    with LOCALE_LOCK:
        saved = locale.setlocale(locale.LC_ALL)
        try:
            yield locale.setlocale(locale.LC_ALL, name)
        finally:
            locale.setlocale(locale.LC_ALL, saved)


# Let's set a non-US locale
# locale.setlocale(locale.LC_ALL, 'de_DE.UTF-8')

# Example to write a formatted English date
with setlocale("pt_BR"):
    print(datetime.now().strftime("%a, %b"))  # e.g. => "Thu, Jun"

print(locale.getlocale(locale.LC_ALL))
# Example to read a formatted English date
# with setlocale('C'):
#     mydate = datetime.strptime('Thu, Jun', '%a, %b')
# Out:
# qua, ago
# (None, None)

# %%
import locale
from datetime import datetime

# print(locale.setlocale(locale.LC_ALL, 'pt_BR'))
print(locale.getdefaultlocale())
print(locale.getlocale())
print(datetime.now().strftime("%a, %b"))  # e.g. => "Thu, Jun"
# Out:
# ('pt_BR', 'cp1252')
# (None, None)
# Wed, Aug

# %%
# !pip install Babel

# %%
from babel.dates import format_datetime

# %%
dt = datetime(2007, 4, 1, 15, 30)
format_datetime(dt, "'Wilson' LLL MMM", locale="pt_BR")
# Out:
# 'Wilson abr. abr.'

# %%
url = "'https://www.anbima.com.br/informacoes/merc-sec-debentures/resultados/mdeb_'ddMMMyyyy'_di_percentual.asp'"
format_datetime(dt, url, locale="pt")
# Out:
# 'https://www.anbima.com.br/informacoes/merc-sec-debentures/resultados/mdeb_01abr.2007_di_percentual.asp'

# %%
base64.decodebytes(b"eyJwYWdlTnVtYmVyIjoxLCJwYWdlU2l6ZSI6MjB9")

params = json.dumps({"pageNumber": 1, "pageSize": 999})

params_enc = base64.encodebytes(bytes(params, "utf8")).decode("utf8")

url = f"https://sistemaswebb3-listados.b3.com.br/indexProxy/indexCall/GetStockIndex/{params_enc.strip()}"

res = requests.get(url, verify=False)

res.json()
# Out:
# c:\Users\wilso\Dev\envs\py373-jupyterlab\lib\site-packages\urllib3\connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sistemaswebb3-listados.b3.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# {'page': {'pageNumber': 1,
#   'pageSize': 999,
#   'totalRecords': 612,
#   'totalPages': 1},
#  'header': {'update': '2021-09-06',
#   'startMonth': 9,
#   'endMonth': 12,
#   'year': 2021},
#  'results': [{'company': '3M',
#    'spotlight': 'DRN',
#    'code': 'MMMC34',
#    'indexes': 'BDRX'},
#   {'company': '3R PETROLEUM',
#    'spotlight': 'ON   NM',
#    'code': 'RRRP3',
#    'indexes': 'IBRA,IGCT,IGCX,IGNM,ITAG,SMLL'},
#   {'company': '3TENTOS',
#    'spotlight': 'ON   NM',
#    'code': 'TTEN3',
#    'indexes': 'IGCX,IGNM,ITAG'},
#   {'company': 'AB INBEV',
#    'spotlight': 'DRN',
#    'code': 'ABUD34',
# ...

# %%
base64.decodebytes(
    b"eyJsYW5ndWFnZSI6InB0LWJyIiwicGFnZU51bWJlciI6MSwicGFnZVNpemUiOjIwfQ=="
)
# Out:
# b'{"language":"pt-br","pageNumber":1,"pageSize":20}'

# %%
params = json.dumps({"language": "pt-br", "pageNumber": 1, "pageSize": 999})
params_enc = base64.encodebytes(bytes(params, "utf8")).decode("utf8")
url = f"https://sistemaswebb3-listados.b3.com.br/indexProxy/indexCall/GetFreeFloatIndex/{params_enc.strip()}"

# %%
url
# Out:
# 'https://sistemaswebb3-listados.b3.com.br/indexProxy/indexCall/GetFreeFloatIndex/eyJsYW5ndWFnZSI6ICJwdC1iciIsICJwYWdlTnVtYmVyIjogMSwgInBhZ2VTaXplIjogOTk5fQ=='

# %%
res = requests.get(url, verify=False)
# Out:
# C:\Users\wilso\anaconda3\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sistemaswebb3-listados.b3.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
res.json()
# Out:
# {'page': {'pageNumber': 1,
#   'pageSize': 999,
#   'totalRecords': 354,
#   'totalPages': 1},
#  'header': {'update': '2021-08-13',
#   'startMonth': 5,
#   'endMonth': 8,
#   'year': 2021},
#  'results': [{'code': 'AALR3',
#    'stock': 'ALLIAR',
#    'type': 'ON   NM',
#    'freeFloat': '43.756.055'},
#   {'code': 'ABCB4',
#    'stock': 'ABC BRASIL',
#    'type': 'PN   N2',
#    'freeFloat': '69.079.780'},
#   {'code': 'ABEV3',
#    'stock': 'AMBEV S/A',
#    'type': 'ON',
#    'freeFloat': '4.358.814.864'},
#   {'code': 'AERI3',
#    'stock': 'AERIS',
#    'type': 'ON   NM',
#    'freeFloat': '218.058.827'},
#   {'code': 'AESB3',
#    'stock': 'AES BRASIL',
#    'type': 'ON   NM',
#    'freeFloat': '218.241.191'},
#   {'code': 'AGRO3',
#    'stock': 'BRASILAGRO',
#    'type': 'ON   NM',
#    'freeFloat': '51.771.532'},
#   {'code': 'AGXY3',
#    'stock': 'AGROGALAXY',
#    'type': 'ON   NM',
#    'freeFloat': '63.417.143'},
#   {'code': 'ALLD3',
#    'stock': 'ALLIED',
# ...

# %%
url = "https://sistemaswebb3-listados.b3.com.br/indexProxy/indexCall/GetPortfolioDay/eyJsYW5ndWFnZSI6InB0LWJyIiwicGFnZU51bWJlciI6MSwicGFnZVNpemUiOjIwLCJpbmRleCI6IklCWFgiLCJzZWdtZW50IjoiMSJ9"

# %%
base64.decodebytes(
    b"eyJsYW5ndWFnZSI6InB0LWJyIiwicGFnZU51bWJlciI6MSwicGFnZVNpemUiOjIwLCJpbmRleCI6IklCWFgiLCJzZWdtZW50IjoiMSJ9"
)
# Out:
# b'{"language":"pt-br","pageNumber":1,"pageSize":20,"index":"IBXX","segment":"1"}'

# %%
# IBOV,IBRA,IBXX,ICON,IGCT,IGCX,IGNM,ITAG,IVBX,SMLL

params = json.dumps(
    {
        "language": "pt-br",
        "pageNumber": 1,
        "pageSize": 999,
        "index": "IBOV",
        "segment": "1",
    }
)
params_enc = base64.encodebytes(bytes(params, "utf8"))
params_enc = params_enc.replace(b"\n", b"").decode("utf8")

url = f"https://sistemaswebb3-listados.b3.com.br/indexProxy/indexCall/GetPortfolioDay/{params_enc}"
res = requests.get(url, verify=False)
res

if res.status_code == 200:
    print(res.json())
# Out:
# {'page': {'pageNumber': 1, 'pageSize': 999, 'totalRecords': 72, 'totalPages': 1}, 'header': {'date': '06/09/21', 'text': 'Quantidade Teórica Total', 'part': '100,000', 'partAcum': None, 'textReductor': 'Redutor', 'reductor': '1.048.482.471,90641000', 'theoricalQty': '85.002.413.016'}, 'results': [{'segment': None, 'cod': 'ALPA4', 'asset': 'ALPARGATAS', 'type': 'PN      N1', 'part': '0,396', 'partAcum': None, 'theoricalQty': '167.963.777'}, {'segment': None, 'cod': 'ABEV3', 'asset': 'AMBEV S/A', 'type': 'ON', 'part': '2,993', 'partAcum': None, 'theoricalQty': '4.358.814.864'}, {'segment': None, 'cod': 'AMER3', 'asset': 'AMERICANAS', 'type': 'ON      NM', 'part': '0,948', 'partAcum': None, 'theoricalQty': '546.064.815'}, {'segment': None, 'cod': 'ASAI3', 'asset': 'ASSAI', 'type': 'ON      NM', 'part': '0,598', 'partAcum': None, 'theoricalQty': '794.116.430'}, {'segment': None, 'cod': 'B3SA3', 'asset': 'B3', 'type': 'ON      NM', 'part': '3,542', 'partAcum': None, 'theoricalQty': '6.079
# ...

# %%
base64.decodebytes(
    b"eyJwYWdlTnVtYmVyIjoxLCJwYWdlU2l6ZSI6MjAsImxhbmd1YWdlIjoicHQtYnIiLCJpbmRleCI6IklCWFgifQ=="
)
# Out:
# b'{"pageNumber":1,"pageSize":20,"language":"pt-br","index":"IBXX"}'

# %%
# Carteira Mai-Ago 2021
url1 = "https://sistemaswebb3-listados.b3.com.br/indexProxy/indexCall/GetTheoricalPortfolio/eyJwYWdlTnVtYmVyIjoxLCJwYWdlU2l6ZSI6MjAsImxhbmd1YWdlIjoicHQtYnIiLCJpbmRleCI6IklCWFgifQ=="
res1 = requests.get(url1, verify=False)
res1
res1.json()
# Out:
# c:\Users\wilso\Dev\envs\py373-jupyterlab\lib\site-packages\urllib3\connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sistemaswebb3-listados.b3.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# {'page': {'pageNumber': 1,
#   'pageSize': 20,
#   'totalRecords': 100,
#   'totalPages': 5},
#  'header': {'part': '100,000',
#   'theoricalQty': '94.929.755.423',
#   'reductor': '50.805.501,38287742'},
#  'results': [{'cod': 'ABEV3',
#    'asset': 'AMBEV S/A',
#    'type': 'ON',
#    'theoricalQty': '4.358.814.864',
#    'part': '2,832',
#    'cont': 2},
#   {'cod': 'ALPA4',
#    'asset': 'ALPARGATAS',
#    'type': 'PN      N1',
#    'theoricalQty': '167.963.777',
#    'part': '0,374',
#    'cont': 1},
#   {'cod': 'AMER3',
#    'asset': 'AMERICANAS',
#    'type': 'ON      NM',
#    'theoricalQty': '546.064.815',
# ...

# %%
# Carteira do Dia
url2 = "https://sistemaswebb3-listados.b3.com.br/indexProxy/indexCall/GetPortfolioDay/eyJsYW5ndWFnZSI6InB0LWJyIiwicGFnZU51bWJlciI6MSwicGFnZVNpemUiOjIwLCJpbmRleCI6IklCWFgiLCJzZWdtZW50IjoiMSJ9"
res2 = requests.get(url2, verify=False)
res2
res2.json()
# Out:
# c:\Users\wilso\Dev\envs\py373-jupyterlab\lib\site-packages\urllib3\connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sistemaswebb3-listados.b3.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# {'page': {'pageNumber': 1,
#   'pageSize': 20,
#   'totalRecords': 100,
#   'totalPages': 5},
#  'header': {'date': '06/09/21',
#   'text': 'Quantidade Teórica Total',
#   'part': '100,000',
#   'partAcum': None,
#   'textReductor': 'Redutor',
#   'reductor': '50.805.501,38287740',
#   'theoricalQty': '94.929.755.423'},
#  'results': [{'segment': None,
#    'cod': 'ALPA4',
#    'asset': 'ALPARGATAS',
#    'type': 'PN      N1',
#    'part': '0,374',
#    'partAcum': None,
#    'theoricalQty': '167.963.777'},
#   {'segment': None,
#    'cod': 'ABEV3',
#    'asset': 'AMBEV S/A',
#    'type': 'ON',
#    'part': '2,832',
# ...

# %%
# 2a Prévia
url3 = "https://sistemaswebb3-listados.b3.com.br/indexProxy/indexCall/GetQuartelyPreview/eyJwYWdlTnVtYmVyIjoxLCJwYWdlU2l6ZSI6MjAsImxhbmd1YWdlIjoicHQtYnIiLCJpbmRleCI6IklCWFgifQ=="
res3 = requests.get(url3, verify=False)
res3
res3.json()
# Out:
# c:\Users\wilso\Dev\envs\py373-jupyterlab\lib\site-packages\urllib3\connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'sistemaswebb3-listados.b3.com.br'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# {'page': {'pageNumber': 1,
#   'pageSize': 20,
#   'totalRecords': 100,
#   'totalPages': 5},
#  'header': {'part': '100,000',
#   'theoricalQty': '94.929.755.423',
#   'reductor': '50.756.206,17246645'},
#  'results': [{'cod': 'ALPA4',
#    'asset': 'ALPARGATAS',
#    'type': 'PN      N1',
#    'theoricalQty': '167.963.777',
#    'part': '0,389',
#    'cont': 1},
#   {'cod': 'ABEV3',
#    'asset': 'AMBEV S/A',
#    'type': 'ON',
#    'theoricalQty': '4.358.814.864',
#    'part': '2,828',
#    'cont': 2},
#   {'cod': 'AMER3',
#    'asset': 'AMERICANAS',
#    'type': 'ON      NM',
#    'theoricalQty': '546.064.815',
# ...

# %%
print(
    res1.json()["header"]["theoricalQty"],
    res2.json()["header"]["theoricalQty"],
    res3.json()["header"]["theoricalQty"],
)
# Out:
# 94.929.755.423 94.929.755.423 94.929.755.423

# %%
res3.json()
# Out:
# {'page': {'pageNumber': 1,
#   'pageSize': 20,
#   'totalRecords': 100,
#   'totalPages': 5},
#  'header': {'part': '100,000',
#   'theoricalQty': '94.902.522.076',
#   'reductor': '51.183.189,84276990'},
#  'results': [{'cod': 'ALPA4',
#    'asset': 'ALPARGATAS',
#    'type': 'PN      N1',
#    'theoricalQty': '167.963.777',
#    'part': '0,373',
#    'cont': 1},
#   {'cod': 'ABEV3',
#    'asset': 'AMBEV S/A',
#    'type': 'ON',
#    'theoricalQty': '4.358.814.864',
#    'part': '2,708',
#    'cont': 2},
#   {'cod': 'AMER3',
#    'asset': 'AMERICANAS',
#    'type': 'ON      NM',
#    'theoricalQty': '546.064.815',
#    'part': '0,879',
#    'cont': 3},
#   {'cod': 'ASAI3',
#    'asset': 'ASSAI',
#    'type': 'ON  EB  NM',
#    'theoricalQty': '794.116.430',
#    'part': '0,526',
#    'cont': 4},
#   {'cod': 'AZUL4',
#    'asset': 'AZUL',
#    'type': 'PN      N2',
#    'theoricalQty': '327.262.616',
#    'part': '0,449',
#    'cont': 5},
#   {'cod': 'B3SA3',
#    'asset': 'B3',
# ...

# %% [markdown]
# IBXX
# IBXL
# IBOV
# IBRA

# %% [markdown]
# ### Obter séries históricas de índices

# %%
#
url = "https://sistemaswebb3-listados.b3.com.br/indexStatisticsProxy/IndexCall/GetPortfolioDay/eyJpbmRleCI6IklCUkEiLCJsYW5ndWFnZSI6InB0LWJyIiwieWVhciI6IjIwMjEifQ=="

# %%
base64.decodebytes(
    b"eyJpbmRleCI6IklCUkEiLCJsYW5ndWFnZSI6InB0LWJyIiwieWVhciI6IjIwMjEifQ=="
)
# Out:
# b'{"index":"IBRA","language":"pt-br","year":"2021"}'

# %%
# Taxa de crescimento

"https://sistemaswebb3-listados.b3.com.br/indexStatisticsProxy/IndexCall/GetAverageGrowthRate/eyJpbmRleCI6IklCUkEiLCJsYW5ndWFnZSI6InB0LWJyIiwieWVhciI6MjAxMSwieWVhckVuZCI6MjAyMX0="

# %%
# Variação anual R$/U$

"https://sistemaswebb3-listados.b3.com.br/indexStatisticsProxy/IndexCall/GetYearlyVariation/eyJwYWdlTnVtYmVyIjoxLCJwYWdlU2l6ZSI6MjAsImluZGV4IjoiSUJSQSIsImxhbmd1YWdlIjoicHQtYnIiLCJ5ZWFyIjoxOTY4LCJ5ZWFyRW5kIjoyMDIxfQ=="

# %%
# Evolução mensal

"https://sistemaswebb3-listados.b3.com.br/indexStatisticsProxy/IndexCall/GetMonthlyEvolution/eyJpbmRleCI6IklCUkEiLCJsYW5ndWFnZSI6InB0LWJyIiwiZGF0ZUluaXRpYWwiOiIyMDEwLTAxLTAxIiwiZGF0ZUZpbmFsIjoiMjAyMS0xMi0zMSJ9"

# %%
# Volatilidade mensal

"https://sistemaswebb3-listados.b3.com.br/indexStatisticsProxy/IndexCall/GetMensalVolatility/eyJpbmRleCI6IklCUkEiLCJsYW5ndWFnZSI6InB0LWJyIiwieWVhciI6MjAxMCwieWVhckVuZCI6MjAyMX0="

# %%
# Valor de mercado

"https://sistemaswebb3-listados.b3.com.br/indexStatisticsProxy/IndexCall/GetMarketValue/eyJwYWdlTnVtYmVyIjoxLCJwYWdlU2l6ZSI6MjAsImluZGV4IjoiSUJSQSIsImxhbmd1YWdlIjoicHQtYnIiLCJ5ZWFyIjoiMjAyMSJ9"
# Out:
# 'https://sistemaswebb3-listados.b3.com.br/indexStatisticsProxy/IndexCall/GetMarketValue/eyJwYWdlTnVtYmVyIjoxLCJwYWdlU2l6ZSI6MjAsImluZGV4IjoiSUJSQSIsImxhbmd1YWdlIjoicHQtYnIiLCJ5ZWFyIjoiMjAyMSJ9'

# %%
# Recordes anuais

"https://sistemaswebb3-listados.b3.com.br/indexStatisticsProxy/IndexCall/GetLargestClosingVolume/eyJwYWdlTnVtYmVyIjoxLCJwYWdlU2l6ZSI6MjAsImluZGV4IjoiSUJSQSIsImxhbmd1YWdlIjoicHQtYnIiLCJ5ZWFyIjoxOTY4LCJ5ZWFyRW5kIjoyMDIxfQ=="
"https://sistemaswebb3-listados.b3.com.br/indexStatisticsProxy/IndexCall/GetSmallestClosingVolume/eyJwYWdlTnVtYmVyIjoxLCJwYWdlU2l6ZSI6MjAsImluZGV4IjoiSUJSQSIsImxhbmd1YWdlIjoicHQtYnIiLCJ5ZWFyIjoxOTY4LCJ5ZWFyRW5kIjoyMDIxfQ=="
