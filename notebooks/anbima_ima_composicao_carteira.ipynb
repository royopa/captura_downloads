# %%
from datetime import datetime
import os
import pandas as pd
from pathlib import Path
from utils import get_engine

data_atual = datetime.now()
data_arquivo = data_atual.strftime('%Y%m%d')
file_path = os.path.join('..', 'downloads_bulk', f'{data_arquivo}_anbima_ima_composicao_carteira.txt')
df = pd.read_csv(file_path, sep='@', encoding='utf8', decimal=',', thousands='.', skiprows=0)
del df['2']

a_renomear = {
    '2':'2',
    'Data de Referência':'DT_REF',
    'INDICE':'NO_INDICE',
    'Títulos':'NO_TITULO',
    'Data de Vencimento':'DT_VENCTO',
    'Código SELIC':'CO_SELIC',
    'Código ISIN':'CO_ISIN',
    'Taxa Indicativa (% a.a.)':'PC_TAXA_INDICATIVA',
    'PU (R$)':'VR_PU',
    'PU de Juros (R$)':'VR_PU_JUROS',
    'Quantidade (1.000 títulos)':'NU_QTDE_TITULOS',
    'Quantidade Teórica (1.000 títulos)':'VR_QTDE_TEORICA',
    'Carteira a Mercado (R$ mil)':'VR_CARTEIRA_MERCADO',
    'Peso (%)':'PC_PESO',
    'Prazo (d.u.)':'NU_PRAZO',
    'Duration (d.u.)':'VR_DURATION',
    'Número de Operações *':'NU_OPERACOES',
    'Quant. Negociada (1.000 títulos) *':'NU_QTDE_NEGOCIADA',
    'Valor Negociado (R$ mil) *':'VR_VALOR_NEGOCIADO',
    'PMR':'NU_PMR',
    'Convexidade':'VR_CONVEXIDADE',
}

df = df.rename(columns=a_renomear)

df['DT_REF'] = pd.to_datetime(df['DT_REF'], format='%d/%m/%Y')
df['DT_VENCTO'] = pd.to_datetime(df['DT_VENCTO'], format='%d/%m/%Y')

file_name = Path(file_path).name
schema = file_name.split('_')[1]
table_name = file_name.split('_anbima_')[1].split('.')[0]
df.head().to_sql(table_name, con=get_engine(), if_exists='replace', index=False, schema=schema)

df.to_csv(file_path.replace('.txt', '.csv'), sep=';', index=False, encoding='utf-8', lineterminator='\n')

print('Fim da execução')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~/projects/captura_downloads/.venv/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File ~/projects/captura_downloads/.venv/lib/python3.12/site-packages/sqlalchemy/engine/default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ...
